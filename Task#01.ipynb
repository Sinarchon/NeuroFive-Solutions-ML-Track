# %%
import pandas as pd
import numpy as np

df = pd.read_csv('titanic.csv')

df.head()

# %%
df.info()

# %%
df.describe()

# %%
print("Rows & Columns:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

print("\nColumn Data Types:")
print(df.dtypes)

# %% [markdown]
# ### Titanic Dataset - Exploratory Data Analysis Summary
#
# * **Dataset Dimensions:** The dataset contains **891 rows** and **12 columns**.
# * **Missing Values:** `Cabin` is missing 687 values (~77%), `Age` is missing 177 values (~20%), and `Embarked` is missing 2 values.
# * **Feature Classification:** Identified **7 numerical features** (like `Age`, `Fare`, `Survived`) and **5 categorical features** (like `Sex`, `Name`, `Cabin`).
# * **Key Finding:** The average survival rate in this dataset is **38.4%**, and ticket prices (`Fare`) have extreme outliers ranging up to $512.
# * **Next Steps:** Prior to modeling, `Age` will need median imputation, and `Cabin` should likely be converted into a binary flag or dropped due to heavy missingness.
